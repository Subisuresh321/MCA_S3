# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([1,5,3,3,3,3])
y=np.array([3,3,3,1,3,5])
plt.plot(x,y,marker='+',color="r",ms=25,mec='r',mfc='g')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

a1 = np.array([1, 2, 3, 4])
a2 = np.array([5, 6, 7, 8])
x = np.array([0, 1, 2, 3])

plt.plot(x, a1, marker=".", label="a1")
plt.plot(x, a2, marker=".", label="a2")
plt.show()

# %%
a1 = np.array([1, 2, 3, 4])
a2 = np.array([5, 6, 7, 8])

plt.subplot(2,2,1)
plt.plot(a1)
plt.xlabel("Time")
plt.ylabel("Distance")
plt.subplot(2,2,2)
plt.plot(a2)
plt.subplot(2,2,3)
plt.plot(a1)
plt.subplot(2,2,4)
plt.plot(a2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 6
#       4 plt.subplot(2,2,1)
#       5 plt.plot(a1)
# ----> 6 plt.xlabel("Time")
#       7 plt.ylabel("Distance")
#       8 plt.subplot(2,2,2)
#
# TypeError: 'str' object is not callable

# %%
import seaborn as sns
BMI = np.array([17,18,19,20])
age = np.array([18,24,32,42])
sugar=np.array(['yes','No','yes','No'])
sns.scatterplot(x=BMI,y=age, hue=sugar,palette={'yes':'red','No':'green'})
# Out:
# <Axes: >
